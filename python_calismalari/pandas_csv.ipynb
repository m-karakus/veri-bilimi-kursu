# %%
import pandas as pd

# %%
pd.read_csv('stock_data.csv')
# Out:
#   Stock Data     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0    tickers            eps    revenue      price         people
# 1      GOOGL          27.82         87        845     lerry page
# 2        WMT           6.61        484         65           n.a.
# 3       MSFT             -1         85         64     bill gates
# 4        RIL  not available         50       1023  mukesh ambani
# 5       TATA            5.6         -1       n.a.     retan tata

# %%
pd.read_csv('stock_data.csv', header=1)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     lerry page
# 1     WMT           6.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3     RIL  not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     retan tata

# %%
pd.read_csv('stock_data.csv', header=None,
            names=['tickers','eps','revenue','price','people']
            )
# Out:
#       tickers            eps  revenue  price         people
# 0  Stock Data            NaN      NaN    NaN            NaN
# 1     tickers            eps  revenue  price         people
# 2       GOOGL          27.82       87    845     lerry page
# 3         WMT           6.61      484     65           n.a.
# 4        MSFT             -1       85     64     bill gates
# 5         RIL  not available       50   1023  mukesh ambani
# 6        TATA            5.6       -1   n.a.     retan tata

# %%
pd.read_csv('stock_data.csv', nrows=1)
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  lerry page

# %%
pd.read_csv('stock_data.csv', na_values=['not available','n.a.'])
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     lerry page
# 1     WMT   6.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3     RIL    NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     retan tata

# %%
df = pd.read_csv('stock_data.csv', na_values={
    'eps':['not available','n.a.'],
    'revenue':[-1],
    'people':['n.a.']
})

df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     lerry page
# 1     WMT   6.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     retan tata

# %%
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     lerry page
# 1     WMT   6.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3     RIL    NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     retan tata

# %%
df.to_csv('new.csv')

# %%
df.to_csv('new.csv',index=False)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv('new.csv',columns=['tickers','eps'],index=False,)

# %%
df.to_csv('new.csv',header=False)

# %%
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 639.7 kB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
df.to_excel('stock_data.xlsx')

# %%
def convertpeople(cell):
    if cell == 'n.a.':
        cell = 'sam walton'
    return cell

    
pd.read_excel('stock_data.xlsx','ttt',converters={
    'people':convertpeople
})
# Out:
#    Unnamed: 0 tickers    eps  revenue price         people
# 0           0   GOOGL  27.82     87.0   845     lerry page
# 1           1     WMT   6.61    484.0    65     sam walton
# 2           2    MSFT  -1.00     85.0    64     bill gates
# 3           3     RIL    NaN     50.0  1023  mukesh ambani
# 4           4    TATA   5.60      NaN  n.a.     retan tata
